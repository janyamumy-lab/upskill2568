# %% [markdown]
# <a href="https://colab.research.google.com/github/janyamumy-lab/upskill2568/blob/main/Untitled97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

#โหลด dataset
df = pd.read_csv('/content/drive/MyDrive/Dataset/retail_sales_dataset.csv')

#ขั้นที่ 1: ดูโครงสร้างข้อมูล
print(df.shape)   #จำนวนแถวและคอลัมน์
df.head()         #แสดงตัวอย่างข้อมูล 5 แถวแรก
df.info()         #แสดงรายละเอียดคอลัมน์ ชนิดข้อมูล missing

#ขั้นที่ 2: สถิติเบื้องต้น
df.describe()     #Mean, Max, Min, Std, Percentile...
df.isnull().sum() #จำนวน missing value

#สำรวจ Category
df['Category'].value_counts() #ค่าของข้อมูล
# Out:
# (1000, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction ID  1000 non-null   int64
#  1   Date            1000 non-null   object
#  2   Customer ID     1000 non-null   object
#  3   Gender          1000 non-null   object
#  4   Age             1000 non-null   int64
#  5   Category        1000 non-null   object
#  6   Quantity        1000 non-null   int64
#  7   UnitPrice       1000 non-null   int64
#  8   Total_Amount    1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB
# Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64
